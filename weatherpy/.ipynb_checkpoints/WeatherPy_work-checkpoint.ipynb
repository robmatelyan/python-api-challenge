# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['kapaa',
#  'lata',
#  'guerrero negro',
#  'tasiilaq',
#  'taga',
#  'brae',
#  'kamaishi',
#  'vaini',
#  'naze',
#  'qaanaaq',
#  'karakendzha',
#  'deputatskiy',
#  'hermanus',
#  'teya',
#  'ushuaia',
#  'ivybridge',
#  'port alfred',
#  'khatanga',
#  'georgetown',
#  'saldanha',
#  'rikitea',
#  'busselton',
#  'albany',
#  'saleaula',
#  'tacuarembo',
#  'belushya guba',
#  'atuona',
#  'hilo',
#  'omboue',
#  'barentsburg',
#  'port elizabeth',
#  'inderborskiy',
#  'avarua',
#  'forotic',
#  'raudeberg',
#  'upernavik',
#  'puerto ayora',
#  'caravelas',
#  'nalut',
#  'grindavik',
#  'grand river south east',
#  'husavik',
#  'mys shmidta',
#  'karonga',
#  'bethel',
#  'tigzirt',
#  'taolanaro',
#  'jamestown',
#  'butaritari',
#  'saint-philippe',
#  'yellowknife',
#  'sao joao do piaui',
#  'iqaluit',
#  'hukuntsi',
#  'darnah',
#  'svetlaya',
#  'nikolskoye',
#  'abu dhabi',
#  'cape town',
#  'alice springs',
#  'williams lake',
#  'gamboma',
#  'maarianhamina',
#  'voyvozh',
#  'tres arroyos',
#  'el badari',
#  'esperance',
#  'illoqqortoormiut',
#  'castlerea',
#  'lavrentiya',
#  'castro',
#  'ercis',
#  'camden',
#  'ziro',
#  'pacific grove',
#  'hobart',
#  'jalu',
#  'chuy',
#  'hambantota',
#  'gornyy',
#  'filingue',
#  'carnarvon',
#  'sinkat',
#  'kanigoro',
#  'dikson',
#  'katsuura',
#  'mookane',
#  'talcahuano',
#  'rio gallegos',
#  'arandis',
#  'padang',
#  'kajaani',
#  'atasu',
#  'kendari',
#  'mataura',
#  'yarmouth',
#  'northam',
#  'aklavik',
#  'attawapiskat',
#  'verdun',
#  'thompson',
#  'bambous virieux',
#  'vao',
#  'carahue',
#  'indramayu',
#  'wajima',
#  'punta arenas',
#  'barrow',
#  'aitape',
#  'baruun-urt',
#  'sitka',
#  'hithadhoo',
#  'plettenberg bay',
#  'gat',
#  'mar del plata',
#  'los llanos de aridane',
#  'kirakira',
#  'new norfolk',
#  'sur',
#  'barbar',
#  'chima',
#  'saint-louis',
#  'nguiu',
#  'longyearbyen',
#  'boa vista',
#  'ostrovnoy',
#  'codrington',
#  'karratha',
#  'ribeira grande',
#  'vaitupu',
#  'quatre cocos',
#  'provideniya',
#  'la roche-sur-yon',
#  'khovu-aksy',
#  'ayame',
#  'axim',
#  'ilulissat',
#  'saskylakh',
#  'mora',
#  'anadyr',
#  'mehamn',
#  'pisco',
#  'mount gambier',
#  'saint-francois',
#  'klamath falls',
#  'ippy',
#  'victoria',
#  'kahului',
#  'bilibino',
#  'kaitangata',
#  'san patricio',
#  'lebu',
#  'bredasdorp',
#  'sosnovo-ozerskoye',
#  'souillac',
#  'vardo',
#  'arraial do cabo',
#  'mareeba',
#  'airai',
#  'baoqing',
#  'salalah',
#  'alenquer',
#  'cherskiy',
#  'chara',
#  'kencong',
#  'seoul',
#  'samusu',
#  'pandan',
#  'iskateley',
#  'dodola',
#  'cidreira',
#  'coihaique',
#  'kokopo',
#  'borogontsy',
#  'rawannawi',
#  'viedma',
#  'berlevag',
#  'najran',
#  'dudinka',
#  'christchurch',
#  'yuyao',
#  'kieta',
#  'harper',
#  'tsihombe',
#  'ulaangom',
#  'ostersund',
#  'college',
#  'harer',
#  'qasigiannguit',
#  'udachnyy',
#  'alofi',
#  'iquitos',
#  'zyryanka',
#  'batagay-alyta',
#  'wanning',
#  'lompoc',
#  'arlit',
#  'ponta do sol',
#  'muravlenko',
#  'bluff',
#  'prince rupert',
#  'zhuhai',
#  'east london',
#  'naftah',
#  'vuktyl',
#  'asfi',
#  'taoudenni',
#  'balabac',
#  'tyukalinsk',
#  'ancud',
#  'vila velha',
#  'chichica',
#  'norman wells',
#  'tevaitoa',
#  'champerico',
#  'havelock',
#  'bereznik',
#  'chokurdakh',
#  'waingapu',
#  'narsaq',
#  'samarai',
#  'isangel',
#  'faanui',
#  'zhigansk',
#  'port lincoln',
#  'hamilton',
#  'miri',
#  'grand gaube',
#  'mogok',
#  'haibowan',
#  'bengkulu',
#  'presidente venceslau',
#  'necochea',
#  'sitarganj',
#  'nabire',
#  'horadiz',
#  'ust-kamchatsk',
#  'dillon',
#  'kodiak',
#  'bayir',
#  'cayenne',
#  'cururupu',
#  'maragogi',
#  'tromso',
#  'nanortalik',
#  'kargil',
#  'williamsburg',
#  'mahebourg',
#  'ondangwa',
#  'walvis bay',
#  'pangnirtung',
#  'coria',
#  'shamary',
#  'ciudad guayana',
#  'bodden town',
#  'khoy',
#  'carrickmacross',
#  'komsomolskiy',
#  'hobyo',
#  'la ronge',
#  'bonavista',
#  'bargal',
#  'nuuk',
#  'xining',
#  'haines junction',
#  'mahajanga',
#  'geraldton',
#  'shingu',
#  'kiama',
#  'upata',
#  'poso',
#  'sagua la grande',
#  'tuktoyaktuk',
#  'isiro',
#  'yatsuo',
#  'kenai',
#  'north bend',
#  'thinadhoo',
#  'tatsinskaya',
#  'kavieng',
#  'birao',
#  'port hedland',
#  'teahupoo',
#  'windsor',
#  'sao joao da barra',
#  'leua',
#  'buguruslan',
#  'nome',
#  'edgewater',
#  'thyboron',
#  'touros',
#  'magadan',
#  'fevralsk',
#  'lakes entrance',
#  'ordynskoye',
#  'mount isa',
#  'sobolevo',
#  'parole',
#  'lincoln',
#  'severo-kurilsk',
#  'abong mbang',
#  'puerto el triunfo',
#  'coquimbo',
#  'le port',
#  'wakkanai',
#  'sola',
#  'lagoa',
#  'shitkino',
#  'henties bay',
#  'mocuba',
#  'bowen',
#  'tatvan',
#  'rocha',
#  'blonduos',
#  'tuatapere',
#  'wokha',
#  'fuling',
#  'saquena',
#  'vestmannaeyjar',
#  'ulladulla',
#  'kruisfontein',
#  'garden acres',
#  'sept-iles',
#  'saint george',
#  'soyo',
#  'toora-khem',
#  'troitsk',
#  'gizo',
#  'shubarkuduk',
#  'ponta delgada',
#  'stornoway',
#  'pevek',
#  'emba',
#  'tyukhtet',
#  'chumikan',
#  'san cristobal',
#  'birin',
#  'aktau',
#  'cristalina',
#  'la plata',
#  'leningradskiy',
#  'barra patuca',
#  'aurillac',
#  'ishim',
#  'sao filipe',
#  'dunedin',
#  'tacoronte',
#  'marcona',
#  'prieska',
#  'marsabit',
#  'ayan',
#  'sorvag',
#  'la paz',
#  'taksimo',
#  'margate',
#  'ipswich',
#  'yumen',
#  'port blair',
#  'dole',
#  'avera',
#  'uruzgan',
#  'ruidoso',
#  'akyab',
#  'hargeysa',
#  'torbay',
#  'port-gentil',
#  'pulivendla',
#  'amderma',
#  'saint-joseph',
#  'longlac',
#  'manokwari',
#  'cabo san lucas',
#  'dingle',
#  'moose factory',
#  'baneh',
#  'luderitz',
#  'fort nelson',
#  'posadas',
#  'verkhnya syrovatka',
#  'surt',
#  'geesthacht',
#  'aktanysh',
#  'ixtapa',
#  'dipkarpaz',
#  'hami',
#  'maxixe',
#  'topchanchi',
#  'tezu',
#  'kashi',
#  'flin flon',
#  'quang ngai',
#  'suao',
#  'dodge city',
#  'maraa',
#  'red bluff',
#  'clyde river',
#  'sibolga',
#  'praia',
#  'gamba',
#  'kudahuvadhoo',
#  'clarksville',
#  'belance',
#  'comodoro rivadavia',
#  'srednekolymsk',
#  'caltanissetta',
#  'namibe',
#  'ketchikan',
#  'murray bridge',
#  'sioux lookout',
#  'walla walla',
#  'dargaville',
#  'jiddah',
#  'casper',
#  'palabuhanratu',
#  'mizdah',
#  'yarqa',
#  'iquique',
#  'halifax',
#  'shilka',
#  'catamarca',
#  'wahran',
#  'mendi',
#  'tura',
#  'preobrazheniye',
#  'gumdag',
#  'kavaratti',
#  'kambove',
#  'sivaki',
#  'hasaki',
#  'burnie',
#  'sayan',
#  'westport',
#  'massakory',
#  'kawana waters',
#  'khomeynishahr',
#  'yar-sale',
#  'savalou',
#  'tiksi',
#  'puerto quijarro',
#  'barcelona',
#  'weihe',
#  'semporna',
#  'bagaha',
#  'shenjiamen',
#  'calbuco',
#  'khash',
#  'pismo beach',
#  'torez',
#  'nioki',
#  'worthing',
#  'naron',
#  'stykkisholmur',
#  'chauny',
#  'kumhari',
#  'eston',
#  'klaksvik',
#  'nizhneyansk',
#  'menongue',
#  'lunenburg',
#  'saint-leu',
#  'sambava',
#  'chirongui',
#  'toliary',
#  'mugur-aksy',
#  'vershino-darasunskiy',
#  'xichang',
#  'zachagansk',
#  'acapulco',
#  'saint-claude',
#  'flic en flac',
#  'chernyshevskiy',
#  'floro',
#  'hihifo',
#  'ugoofaaru',
#  'grand centre',
#  'flinders',
#  'elmira',
#  'korla',
#  'kargasok',
#  'otradnoye',
#  'alcudia',
#  'palmer',
#  'pereslavl-zalesskiy',
#  'cairns',
#  'porto novo',
#  'nishihara',
#  'ahipara',
#  'conceicao do araguaia',
#  'moron',
#  'poum',
#  'abha',
#  'kuloy',
#  'cockburn town',
#  'takoradi',
#  'ngunguru',
#  'iralaya',
#  'brigantine',
#  'tagusao',
#  'solovetskiy',
#  'chicama',
#  'edd',
#  'bahia de caraquez',
#  'el dorado',
#  'svetlogorsk',
#  'roma',
#  'fortuna',
#  'alotau',
#  'grand-lahou',
#  'severo-yeniseyskiy',
#  'san lorenzo',
#  'les cayes',
#  'moramanga',
#  'smestad',
#  'umzimvubu',
#  'texarkana',
#  'kuhestan',
#  'palu',
#  'dali',
#  'sibiti',
#  'port macquarie',
#  'salem',
#  'lolua',
#  'port augusta',
#  'kununurra',
#  'luanda',
#  'bendigo',
#  'shahr-e kord',
#  'jiangyou',
#  'ballina',
#  'bathsheba',
#  'kawalu',
#  'bahia honda',
#  'mayo',
#  'trinidad',
#  'bilma',
#  'howard springs',
#  'csolnok',
#  'santa marta',
#  'constitucion',
#  'kidal',
#  'wattegama',
#  'livramento',
#  'orchard homes',
#  'satitoa',
#  'zmeinogorsk',
#  'mangrol',
#  'coahuayana',
#  'aykhal',
#  'belaya gora',
#  'koumac',
#  'istok',
#  'luau',
#  'muros',
#  'faya',
#  'hirara',
#  'qaqortoq',
#  'vikindu',
#  'vaitape',
#  'abu samrah',
#  'okhotsk',
#  'rexburg',
#  'gazli',
#  'mingguang',
#  'ucluelet',
#  'santiago',
#  'olafsvik',
#  'jinchang',
#  'salvador',
#  'paamiut',
#  'cockburn harbour',
#  'tunduru',
#  'kralendijk',
#  'nouadhibou',
#  'finschhafen',
#  'sokoto',
#  'te anau',
#  'pekalongan',
#  'hutchinson',
#  'nova olinda do norte',
#  'antofagasta',
#  'lorengau',
#  'pitimbu',
#  'biak',
#  'meulaboh',
#  'bagotville',
#  'mayma',
#  'villamontes',
#  'ko samui',
#  'niort',
#  'bayan',
#  'puerto varas',
#  'chapais',
#  'adrar',
#  'mehran',
#  'asau',
#  'ushtobe',
#  'wynyard',
#  'dakar',
#  'luganville',
#  'bosaso',
#  'bentiu',
#  'yinchuan',
#  'gazojak',
#  'kodinsk',
#  'davila',
#  'marsa matruh',
#  'talnakh']

# %%
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create a variable for the openweather api 
url = "http://api.openweathermap.org/data/2.5/weather?"

# create sample city list as working list to avoid api limits
sample_cities = ['moron',
 'fortuna',
 'puerto ayora',
 'busselton',
 'rikitea',
 'yellowknife',
 'bluff',
 'padang',]

# create lists to store returned values from the api
new_city_list = []
latitude_list = []
longitude_list = []
temperature_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []

# create a new url variable
query_url = url + "appid=" + weather_api_key + "&units=imperial&q=" 

# Loop over cities
for city in cities:
    count += 0
    print(f"Processing Record {count}: {city}")
    weather_response = requests.get(query_url + city).json()
    
    try:
        new_city_list.append(weather_response['name'])
        latitude_list.append(weather_response['coord']['lat'])
        longitude_list.append(weather_response['coord']['lon'])
        temperature_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        wind_speed_list.append(weather_response['wind']['speed'])
        country_list.append(weather_response['sys']['country'])
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")
    print("---------------")
print("Data Retrieval Complete")
count = 0
print("---------------")
# Out:
# Processing Record 1229: kapaa
# ---------------
# Processing Record 1229: lata
# ---------------
# Processing Record 1229: guerrero negro
# ---------------
# Processing Record 1229: tasiilaq
# ---------------
# Processing Record 1229: taga
# ---------------
# Processing Record 1229: brae
# ---------------
# Processing Record 1229: kamaishi
# ---------------
# Processing Record 1229: vaini
# ---------------
# Processing Record 1229: naze
# ---------------
# Processing Record 1229: qaanaaq
# ---------------
# Processing Record 1229: karakendzha
# City not found. Skipping...
# ---------------
# Processing Record 1229: deputatskiy
# ---------------
# Processing Record 1229: hermanus
# ---------------
# Processing Record 1229: teya
# ---------------
# Processing Record 1229: ushuaia
# ---------------
# Processing Record 1229: ivybridge
# ---------------
# Processing Record 1229: port alfred
# ---------------
# Processing Record 1229: khatanga
# ---------------
# Processing Record 1229: georgetown
# ---------------
# Processing Record 1229: saldanha
# ---------------
# Processing Record 1229: rikitea
# ---------------
# Processing Record 1229: busselton
# ---------------
# Processing Record 1229: albany
# ---------------
# Processing Record 1229: saleaula
# City not found. Skipping...
# ---------------
# Processing Record 1229: tacuarembo
# ---------------
# Processing Record 1229: belushya guba
# City not found. Skipping...
# ---------------
# Processing Record 1229: atuona
# ---------------
# Processing Record 1229: hilo
# ---------------
# Processing Record 1229: omboue
# ---------------
# Processing Record 1229: barentsburg
# City not found. Skipping...
# ---------------
# Processing Record 1229: port elizabeth
# ---------------
# Processing Record 1229: inderborskiy
# City not found. Skipping...
# ---------------
# Processing Record 1229: avarua
# ---------------
# Processing Record 1229: forotic
# ---------------
# Processing Record 1229: raudeberg
# ---------------
# Processing Record 1229: upernavik
# ---------------
# Processing Record 1229: puerto ayora
# ---------------
# Processing Record 1229: caravelas
# ---------------
# Processing Record 1229: nalut
# ---------------
# Processing Record 1229: grindavik
# ---------------
# Processing Record 1229: grand river south east
# City not found. Skipping...
# ---------------
# Processing Record 1229: husavik
# ---------------
# Processing Record 1229: mys shmidta
# City not found. Skipping...
# ---------------
# Processing Record 1229: karonga
# ---------------
# Processing Record 1229: bethel
# ---------------
# Processing Record 1229: tigzirt
# ---------------
# Processing Record 1229: taolanaro
# City not found. Skipping...
# ---------------
# Processing Record 1229: jamestown
# ---------------
# Processing Record 1229: butaritari
# ---------------
# Processing Record 1229: saint-philippe
# ---------------
# Processing Record 1229: yellowknife
# ---------------
# Processing Record 1229: sao joao do piaui
# ---------------
# Processing Record 1229: iqaluit
# ---------------
# Processing Record 1229: hukuntsi
# ---------------
# Processing Record 1229: darnah
# ---------------
# Processing Record 1229: svetlaya
# ---------------
# Processing Record 1229: nikolskoye
# ---------------
# Processing Record 1229: abu dhabi
# ---------------
# Processing Record 1229: cape town
# ---------------
# Processing Record 1229: alice springs
# ---------------
# Processing Record 1229: williams lake
# ---------------
# Processing Record 1229: gamboma
# ---------------
# Processing Record 1229: maarianhamina
# ---------------
# Processing Record 1229: voyvozh
# ---------------
# Processing Record 1229: tres arroyos
# ---------------
# Processing Record 1229: el badari
# City not found. Skipping...
# ---------------
# Processing Record 1229: esperance
# ---------------
# Processing Record 1229: illoqqortoormiut
# City not found. Skipping...
# ---------------
# Processing Record 1229: castlerea
# ---------------
# Processing Record 1229: lavrentiya
# ---------------
# Processing Record 1229: castro
# ---------------
# Processing Record 1229: ercis
# ---------------
# Processing Record 1229: camden
# ---------------
# Processing Record 1229: ziro
# ---------------
# Processing Record 1229: pacific grove
# ---------------
# Processing Record 1229: hobart
# ---------------
# Processing Record 1229: jalu
# ---------------
# Processing Record 1229: chuy
# ---------------
# Processing Record 1229: hambantota
# ---------------
# Processing Record 1229: gornyy
# ---------------
# Processing Record 1229: filingue
# ---------------
# Processing Record 1229: carnarvon
# ---------------
# Processing Record 1229: sinkat
# City not found. Skipping...
# ---------------
# Processing Record 1229: kanigoro
# ---------------
# Processing Record 1229: dikson
# ---------------
# Processing Record 1229: katsuura
# ---------------
# Processing Record 1229: mookane
# ---------------
# Processing Record 1229: talcahuano
# ---------------
# Processing Record 1229: rio gallegos
# ---------------
# Processing Record 1229: arandis
# ---------------
# Processing Record 1229: padang
# ---------------
# Processing Record 1229: kajaani
# ---------------
# Processing Record 1229: atasu
# ---------------
# Processing Record 1229: kendari
# ---------------
# Processing Record 1229: mataura
# ---------------
# Processing Record 1229: yarmouth
# ---------------
# Processing Record 1229: northam
# ---------------
# Processing Record 1229: aklavik
# ---------------
# Processing Record 1229: attawapiskat
# City not found. Skipping...
# ---------------
# Processing Record 1229: verdun
# ---------------
# Processing Record 1229: thompson
# ---------------
# Processing Record 1229: bambous virieux
# ---------------
# Processing Record 1229: vao
# ---------------
# Processing Record 1229: carahue
# ---------------
# Processing Record 1229: indramayu
# ---------------
# Processing Record 1229: wajima
# ---------------
# Processing Record 1229: punta arenas
# ---------------
# Processing Record 1229: barrow
# ---------------
# Processing Record 1229: aitape
# ---------------
# Processing Record 1229: baruun-urt
# ---------------
# Processing Record 1229: sitka
# ---------------
# Processing Record 1229: hithadhoo
# ---------------
# Processing Record 1229: plettenberg bay
# ---------------
# Processing Record 1229: gat
# ---------------
# Processing Record 1229: mar del plata
# ---------------
# Processing Record 1229: los llanos de aridane
# ---------------
# Processing Record 1229: kirakira
# ---------------
# Processing Record 1229: new norfolk
# ---------------
# Processing Record 1229: sur
# ---------------
# Processing Record 1229: barbar
# City not found. Skipping...
# ---------------
# Processing Record 1229: chima
# ---------------
# Processing Record 1229: saint-louis
# ---------------
# Processing Record 1229: nguiu
# City not found. Skipping...
# ---------------
# Processing Record 1229: longyearbyen
# ---------------
# Processing Record 1229: boa vista
# ---------------
# Processing Record 1229: ostrovnoy
# ---------------
# Processing Record 1229: codrington
# ---------------
# Processing Record 1229: karratha
# ---------------
# Processing Record 1229: ribeira grande
# ---------------
# Processing Record 1229: vaitupu
# City not found. Skipping...
# ---------------
# Processing Record 1229: quatre cocos
# ---------------
# Processing Record 1229: provideniya
# ---------------
# Processing Record 1229: la roche-sur-yon
# ---------------
# Processing Record 1229: khovu-aksy
# ---------------
# Processing Record 1229: ayame
# ---------------
# Processing Record 1229: axim
# ---------------
# Processing Record 1229: ilulissat
# ---------------
# Processing Record 1229: saskylakh
# ---------------
# Processing Record 1229: mora
# ---------------
# Processing Record 1229: anadyr
# ---------------
# Processing Record 1229: mehamn
# ---------------
# Processing Record 1229: pisco
# ---------------
# Processing Record 1229: mount gambier
# ---------------
# Processing Record 1229: saint-francois
# ---------------
# Processing Record 1229: klamath falls
# ---------------
# Processing Record 1229: ippy
# ---------------
# Processing Record 1229: victoria
# ---------------
# Processing Record 1229: kahului
# ---------------
# Processing Record 1229: bilibino
# ---------------
# Processing Record 1229: kaitangata
# ---------------
# Processing Record 1229: san patricio
# ---------------
# Processing Record 1229: lebu
# ---------------
# Processing Record 1229: bredasdorp
# ---------------
# Processing Record 1229: sosnovo-ozerskoye
# ---------------
# Processing Record 1229: souillac
# ---------------
# Processing Record 1229: vardo
# ---------------
# Processing Record 1229: arraial do cabo
# ---------------
# Processing Record 1229: mareeba
# ---------------
# Processing Record 1229: airai
# ---------------
# Processing Record 1229: baoqing
# ---------------
# Processing Record 1229: salalah
# ---------------
# Processing Record 1229: alenquer
# ---------------
# Processing Record 1229: cherskiy
# ---------------
# Processing Record 1229: chara
# ---------------
# Processing Record 1229: kencong
# ---------------
# Processing Record 1229: seoul
# ---------------
# Processing Record 1229: samusu
# City not found. Skipping...
# ---------------
# Processing Record 1229: pandan
# ---------------
# Processing Record 1229: iskateley
# ---------------
# Processing Record 1229: dodola
# ---------------
# Processing Record 1229: cidreira
# ---------------
# Processing Record 1229: coihaique
# ---------------
# Processing Record 1229: kokopo
# ---------------
# Processing Record 1229: borogontsy
# ---------------
# Processing Record 1229: rawannawi
# City not found. Skipping...
# ---------------
# Processing Record 1229: viedma
# ---------------
# Processing Record 1229: berlevag
# ---------------
# Processing Record 1229: najran
# ---------------
# Processing Record 1229: dudinka
# ---------------
# Processing Record 1229: christchurch
# ---------------
# Processing Record 1229: yuyao
# ---------------
# Processing Record 1229: kieta
# ---------------
# Processing Record 1229: harper
# ---------------
# Processing Record 1229: tsihombe
# City not found. Skipping...
# ---------------
# Processing Record 1229: ulaangom
# ---------------
# Processing Record 1229: ostersund
# ---------------
# Processing Record 1229: college
# ---------------
# Processing Record 1229: harer
# ---------------
# Processing Record 1229: qasigiannguit
# ---------------
# Processing Record 1229: udachnyy
# ---------------
# Processing Record 1229: alofi
# ---------------
# Processing Record 1229: iquitos
# ---------------
# Processing Record 1229: zyryanka
# ---------------
# Processing Record 1229: batagay-alyta
# ---------------
# Processing Record 1229: wanning
# ---------------
# Processing Record 1229: lompoc
# ---------------
# Processing Record 1229: arlit
# ---------------
# Processing Record 1229: ponta do sol
# ---------------
# Processing Record 1229: muravlenko
# ---------------
# Processing Record 1229: bluff
# ---------------
# Processing Record 1229: prince rupert
# ---------------
# Processing Record 1229: zhuhai
# ---------------
# Processing Record 1229: east london
# ---------------
# Processing Record 1229: naftah
# City not found. Skipping...
# ---------------
# Processing Record 1229: vuktyl
# ---------------
# Processing Record 1229: asfi
# ---------------
# Processing Record 1229: taoudenni
# ---------------
# Processing Record 1229: balabac
# ---------------
# Processing Record 1229: tyukalinsk
# ---------------
# Processing Record 1229: ancud
# ---------------
# Processing Record 1229: vila velha
# ---------------
# Processing Record 1229: chichica
# ---------------
# Processing Record 1229: norman wells
# ---------------
# Processing Record 1229: tevaitoa
# ---------------
# Processing Record 1229: champerico
# ---------------
# Processing Record 1229: havelock
# ---------------
# Processing Record 1229: bereznik
# ---------------
# Processing Record 1229: chokurdakh
# ---------------
# Processing Record 1229: waingapu
# ---------------
# Processing Record 1229: narsaq
# ---------------
# Processing Record 1229: samarai
# ---------------
# Processing Record 1229: isangel
# ---------------
# Processing Record 1229: faanui
# ---------------
# Processing Record 1229: zhigansk
# ---------------
# Processing Record 1229: port lincoln
# ---------------
# Processing Record 1229: hamilton
# ---------------
# Processing Record 1229: miri
# ---------------
# Processing Record 1229: grand gaube
# ---------------
# Processing Record 1229: mogok
# ---------------
# Processing Record 1229: haibowan
# City not found. Skipping...
# ---------------
# Processing Record 1229: bengkulu
# ---------------
# Processing Record 1229: presidente venceslau
# ---------------
# Processing Record 1229: necochea
# ---------------
# Processing Record 1229: sitarganj
# ---------------
# Processing Record 1229: nabire
# ---------------
# Processing Record 1229: horadiz
# ---------------
# Processing Record 1229: ust-kamchatsk
# City not found. Skipping...
# ---------------
# Processing Record 1229: dillon
# ---------------
# Processing Record 1229: kodiak
# ---------------
# Processing Record 1229: bayir
# ---------------
# Processing Record 1229: cayenne
# ---------------
# Processing Record 1229: cururupu
# ---------------
# Processing Record 1229: maragogi
# ---------------
# Processing Record 1229: tromso
# ---------------
# Processing Record 1229: nanortalik
# ---------------
# Processing Record 1229: kargil
# ---------------
# Processing Record 1229: williamsburg
# ---------------
# Processing Record 1229: mahebourg
# ---------------
# Processing Record 1229: ondangwa
# ---------------
# Processing Record 1229: walvis bay
# ---------------
# Processing Record 1229: pangnirtung
# ---------------
# Processing Record 1229: coria
# ---------------
# Processing Record 1229: shamary
# ---------------
# Processing Record 1229: ciudad guayana
# ---------------
# Processing Record 1229: bodden town
# ---------------
# Processing Record 1229: khoy
# ---------------
# Processing Record 1229: carrickmacross
# ---------------
# Processing Record 1229: komsomolskiy
# ---------------
# Processing Record 1229: hobyo
# ---------------
# Processing Record 1229: la ronge
# ---------------
# Processing Record 1229: bonavista
# ---------------
# Processing Record 1229: bargal
# City not found. Skipping...
# ---------------
# Processing Record 1229: nuuk
# ---------------
# Processing Record 1229: xining
# ---------------
# Processing Record 1229: haines junction
# ---------------
# Processing Record 1229: mahajanga
# ---------------
# Processing Record 1229: geraldton
# ---------------
# Processing Record 1229: shingu
# ---------------
# Processing Record 1229: kiama
# ---------------
# Processing Record 1229: upata
# ---------------
# Processing Record 1229: poso
# ---------------
# Processing Record 1229: sagua la grande
# ---------------
# Processing Record 1229: tuktoyaktuk
# ---------------
# Processing Record 1229: isiro
# ---------------
# Processing Record 1229: yatsuo
# ---------------
# Processing Record 1229: kenai
# ---------------
# Processing Record 1229: north bend
# ---------------
# Processing Record 1229: thinadhoo
# ---------------
# Processing Record 1229: tatsinskaya
# City not found. Skipping...
# ---------------
# Processing Record 1229: kavieng
# ---------------
# Processing Record 1229: birao
# ---------------
# Processing Record 1229: port hedland
# ---------------
# Processing Record 1229: teahupoo
# ---------------
# Processing Record 1229: windsor
# ---------------
# Processing Record 1229: sao joao da barra
# ---------------
# Processing Record 1229: leua
# ---------------
# Processing Record 1229: buguruslan
# ---------------
# Processing Record 1229: nome
# ---------------
# Processing Record 1229: edgewater
# ---------------
# Processing Record 1229: thyboron
# ---------------
# Processing Record 1229: touros
# ---------------
# Processing Record 1229: magadan
# ---------------
# Processing Record 1229: fevralsk
# City not found. Skipping...
# ---------------
# Processing Record 1229: lakes entrance
# ---------------
# Processing Record 1229: ordynskoye
# ---------------
# Processing Record 1229: mount isa
# ---------------
# Processing Record 1229: sobolevo
# ---------------
# Processing Record 1229: parole
# ---------------
# Processing Record 1229: lincoln
# ---------------
# Processing Record 1229: severo-kurilsk
# ---------------
# Processing Record 1229: abong mbang
# ---------------
# Processing Record 1229: puerto el triunfo
# ---------------
# Processing Record 1229: coquimbo
# ---------------
# Processing Record 1229: le port
# ---------------
# Processing Record 1229: wakkanai
# ---------------
# Processing Record 1229: sola
# ---------------
# Processing Record 1229: lagoa
# ---------------
# Processing Record 1229: shitkino
# ---------------
# Processing Record 1229: henties bay
# ---------------
# Processing Record 1229: mocuba
# ---------------
# Processing Record 1229: bowen
# ---------------
# Processing Record 1229: tatvan
# ---------------
# Processing Record 1229: rocha
# ---------------
# Processing Record 1229: blonduos
# City not found. Skipping...
# ---------------
# Processing Record 1229: tuatapere
# ---------------
# Processing Record 1229: wokha
# ---------------
# Processing Record 1229: fuling
# ---------------
# Processing Record 1229: saquena
# ---------------
# Processing Record 1229: vestmannaeyjar
# ---------------
# Processing Record 1229: ulladulla
# ---------------
# Processing Record 1229: kruisfontein
# ---------------
# Processing Record 1229: garden acres
# ---------------
# Processing Record 1229: sept-iles
# ---------------
# Processing Record 1229: saint george
# ---------------
# Processing Record 1229: soyo
# ---------------
# Processing Record 1229: toora-khem
# ---------------
# Processing Record 1229: troitsk
# ---------------
# Processing Record 1229: gizo
# ---------------
# Processing Record 1229: shubarkuduk
# ---------------
# Processing Record 1229: ponta delgada
# ---------------
# Processing Record 1229: stornoway
# ---------------
# Processing Record 1229: pevek
# ---------------
# Processing Record 1229: emba
# ---------------
# Processing Record 1229: tyukhtet
# ---------------
# Processing Record 1229: chumikan
# ---------------
# Processing Record 1229: san cristobal
# ---------------
# Processing Record 1229: birin
# ---------------
# Processing Record 1229: aktau
# ---------------
# Processing Record 1229: cristalina
# ---------------
# Processing Record 1229: la plata
# ---------------
# Processing Record 1229: leningradskiy
# ---------------
# Processing Record 1229: barra patuca
# ---------------
# Processing Record 1229: aurillac
# ---------------
# Processing Record 1229: ishim
# ---------------
# Processing Record 1229: sao filipe
# ---------------
# Processing Record 1229: dunedin
# ---------------
# Processing Record 1229: tacoronte
# ---------------
# Processing Record 1229: marcona
# City not found. Skipping...
# ---------------
# Processing Record 1229: prieska
# ---------------
# Processing Record 1229: marsabit
# ---------------
# Processing Record 1229: ayan
# ---------------
# Processing Record 1229: sorvag
# City not found. Skipping...
# ---------------
# Processing Record 1229: la paz
# ---------------
# Processing Record 1229: taksimo
# ---------------
# Processing Record 1229: margate
# ---------------
# Processing Record 1229: ipswich
# ---------------
# Processing Record 1229: yumen
# ---------------
# Processing Record 1229: port blair
# ---------------
# Processing Record 1229: dole
# ---------------
# Processing Record 1229: avera
# ---------------
# Processing Record 1229: uruzgan
# ---------------
# Processing Record 1229: ruidoso
# ---------------
# Processing Record 1229: akyab
# ---------------
# Processing Record 1229: hargeysa
# ---------------
# Processing Record 1229: torbay
# ---------------
# Processing Record 1229: port-gentil
# ---------------
# Processing Record 1229: pulivendla
# ---------------
# Processing Record 1229: amderma
# City not found. Skipping...
# ---------------
# Processing Record 1229: saint-joseph
# ---------------
# Processing Record 1229: longlac
# City not found. Skipping...
# ---------------
# Processing Record 1229: manokwari
# ---------------
# Processing Record 1229: cabo san lucas
# ---------------
# Processing Record 1229: dingle
# ---------------
# Processing Record 1229: moose factory
# ---------------
# Processing Record 1229: baneh
# ---------------
# Processing Record 1229: luderitz
# ---------------
# Processing Record 1229: fort nelson
# ---------------
# Processing Record 1229: posadas
# ---------------
# Processing Record 1229: verkhnya syrovatka
# ---------------
# Processing Record 1229: surt
# ---------------
# Processing Record 1229: geesthacht
# ---------------
# Processing Record 1229: aktanysh
# ---------------
# Processing Record 1229: ixtapa
# ---------------
# Processing Record 1229: dipkarpaz
# City not found. Skipping...
# ---------------
# Processing Record 1229: hami
# ---------------
# Processing Record 1229: maxixe
# ---------------
# Processing Record 1229: topchanchi
# ---------------
# Processing Record 1229: tezu
# ---------------
# Processing Record 1229: kashi
# ---------------
# Processing Record 1229: flin flon
# ---------------
# Processing Record 1229: quang ngai
# ---------------
# Processing Record 1229: suao
# City not found. Skipping...
# ---------------
# Processing Record 1229: dodge city
# ---------------
# Processing Record 1229: maraa
# ---------------
# Processing Record 1229: red bluff
# ---------------
# Processing Record 1229: clyde river
# ---------------
# Processing Record 1229: sibolga
# ---------------
# Processing Record 1229: praia
# ---------------
# Processing Record 1229: gamba
# ---------------
# Processing Record 1229: kudahuvadhoo
# ---------------
# Processing Record 1229: clarksville
# ---------------
# Processing Record 1229: belance
# ---------------
# Processing Record 1229: comodoro rivadavia
# ---------------
# Processing Record 1229: srednekolymsk
# ---------------
# Processing Record 1229: caltanissetta
# ---------------
# Processing Record 1229: namibe
# ---------------
# Processing Record 1229: ketchikan
# ---------------
# Processing Record 1229: murray bridge
# ---------------
# Processing Record 1229: sioux lookout
# ---------------
# Processing Record 1229: walla walla
# ---------------
# Processing Record 1229: dargaville
# ---------------
# Processing Record 1229: jiddah
# City not found. Skipping...
# ---------------
# Processing Record 1229: casper
# ---------------
# Processing Record 1229: palabuhanratu
# City not found. Skipping...
# ---------------
# Processing Record 1229: mizdah
# ---------------
# Processing Record 1229: yarqa
# ---------------
# Processing Record 1229: iquique
# ---------------
# Processing Record 1229: halifax
# ---------------
# Processing Record 1229: shilka
# ---------------
# Processing Record 1229: catamarca
# ---------------
# Processing Record 1229: wahran
# City not found. Skipping...
# ---------------
# Processing Record 1229: mendi
# ---------------
# Processing Record 1229: tura
# ---------------
# Processing Record 1229: preobrazheniye
# ---------------
# Processing Record 1229: gumdag
# ---------------
# Processing Record 1229: kavaratti
# ---------------
# Processing Record 1229: kambove
# ---------------
# Processing Record 1229: sivaki
# ---------------
# Processing Record 1229: hasaki
# ---------------
# Processing Record 1229: burnie
# ---------------
# Processing Record 1229: sayan
# ---------------
# Processing Record 1229: westport
# ---------------
# Processing Record 1229: massakory
# ---------------
# Processing Record 1229: kawana waters
# City not found. Skipping...
# ---------------
# Processing Record 1229: khomeynishahr
# City not found. Skipping...
# ---------------
# Processing Record 1229: yar-sale
# ---------------
# Processing Record 1229: savalou
# ---------------
# Processing Record 1229: tiksi
# ---------------
# Processing Record 1229: puerto quijarro
# ---------------
# Processing Record 1229: barcelona
# ---------------
# Processing Record 1229: weihe
# ---------------
# Processing Record 1229: semporna
# ---------------
# Processing Record 1229: bagaha
# ---------------
# Processing Record 1229: shenjiamen
# ---------------
# Processing Record 1229: calbuco
# ---------------
# Processing Record 1229: khash
# ---------------
# Processing Record 1229: pismo beach
# ---------------
# Processing Record 1229: torez
# ---------------
# Processing Record 1229: nioki
# ---------------
# Processing Record 1229: worthing
# ---------------
# Processing Record 1229: naron
# ---------------
# Processing Record 1229: stykkisholmur
# ---------------
# Processing Record 1229: chauny
# ---------------
# Processing Record 1229: kumhari
# ---------------
# Processing Record 1229: eston
# ---------------
# Processing Record 1229: klaksvik
# ---------------
# Processing Record 1229: nizhneyansk
# City not found. Skipping...
# ---------------
# Processing Record 1229: menongue
# ---------------
# Processing Record 1229: lunenburg
# ---------------
# Processing Record 1229: saint-leu
# ---------------
# Processing Record 1229: sambava
# ---------------
# Processing Record 1229: chirongui
# ---------------
# Processing Record 1229: toliary
# City not found. Skipping...
# ---------------
# Processing Record 1229: mugur-aksy
# ---------------
# Processing Record 1229: vershino-darasunskiy
# ---------------
# Processing Record 1229: xichang
# ---------------
# Processing Record 1229: zachagansk
# City not found. Skipping...
# ---------------
# Processing Record 1229: acapulco
# ---------------
# Processing Record 1229: saint-claude
# ---------------
# Processing Record 1229: flic en flac
# ---------------
# Processing Record 1229: chernyshevskiy
# ---------------
# Processing Record 1229: floro
# ---------------
# Processing Record 1229: hihifo
# City not found. Skipping...
# ---------------
# Processing Record 1229: ugoofaaru
# ---------------
# Processing Record 1229: grand centre
# City not found. Skipping...
# ---------------
# Processing Record 1229: flinders
# ---------------
# Processing Record 1229: elmira
# ---------------
# Processing Record 1229: korla
# ---------------
# Processing Record 1229: kargasok
# ---------------
# Processing Record 1229: otradnoye
# ---------------
# Processing Record 1229: alcudia
# ---------------
# Processing Record 1229: palmer
# ---------------
# Processing Record 1229: pereslavl-zalesskiy
# ---------------
# Processing Record 1229: cairns
# ---------------
# Processing Record 1229: porto novo
# ---------------
# Processing Record 1229: nishihara
# ---------------
# Processing Record 1229: ahipara
# ---------------
# Processing Record 1229: conceicao do araguaia
# ---------------
# Processing Record 1229: moron
# ---------------
# Processing Record 1229: poum
# ---------------
# Processing Record 1229: abha
# ---------------
# Processing Record 1229: kuloy
# ---------------
# Processing Record 1229: cockburn town
# ---------------
# Processing Record 1229: takoradi
# ---------------
# Processing Record 1229: ngunguru
# ---------------
# Processing Record 1229: iralaya
# ---------------
# Processing Record 1229: brigantine
# ---------------
# Processing Record 1229: tagusao
# ---------------
# Processing Record 1229: solovetskiy
# City not found. Skipping...
# ---------------
# Processing Record 1229: chicama
# ---------------
# Processing Record 1229: edd
# ---------------
# Processing Record 1229: bahia de caraquez
# ---------------
# Processing Record 1229: el dorado
# ---------------
# Processing Record 1229: svetlogorsk
# ---------------
# Processing Record 1229: roma
# ---------------
# Processing Record 1229: fortuna
# ---------------
# Processing Record 1229: alotau
# City not found. Skipping...
# ---------------
# Processing Record 1229: grand-lahou
# ---------------
# Processing Record 1229: severo-yeniseyskiy
# ---------------
# Processing Record 1229: san lorenzo
# ---------------
# Processing Record 1229: les cayes
# ---------------
# Processing Record 1229: moramanga
# ---------------
# Processing Record 1229: smestad
# ---------------
# Processing Record 1229: umzimvubu
# City not found. Skipping...
# ---------------
# Processing Record 1229: texarkana
# ---------------
# Processing Record 1229: kuhestan
# City not found. Skipping...
# ---------------
# Processing Record 1229: palu
# ---------------
# Processing Record 1229: dali
# ---------------
# Processing Record 1229: sibiti
# ---------------
# Processing Record 1229: port macquarie
# ---------------
# Processing Record 1229: salem
# ---------------
# Processing Record 1229: lolua
# City not found. Skipping...
# ---------------
# Processing Record 1229: port augusta
# ---------------
# Processing Record 1229: kununurra
# ---------------
# Processing Record 1229: luanda
# ---------------
# Processing Record 1229: bendigo
# ---------------
# Processing Record 1229: shahr-e kord
# ---------------
# Processing Record 1229: jiangyou
# ---------------
# Processing Record 1229: ballina
# ---------------
# Processing Record 1229: bathsheba
# ---------------
# Processing Record 1229: kawalu
# ---------------
# Processing Record 1229: bahia honda
# ---------------
# Processing Record 1229: mayo
# ---------------
# Processing Record 1229: trinidad
# ---------------
# Processing Record 1229: bilma
# ---------------
# Processing Record 1229: howard springs
# ---------------
# Processing Record 1229: csolnok
# ---------------
# Processing Record 1229: santa marta
# ---------------
# Processing Record 1229: constitucion
# ---------------
# Processing Record 1229: kidal
# ---------------
# Processing Record 1229: wattegama
# ---------------
# Processing Record 1229: livramento
# ---------------
# Processing Record 1229: orchard homes
# ---------------
# Processing Record 1229: satitoa
# City not found. Skipping...
# ---------------
# Processing Record 1229: zmeinogorsk
# ---------------
# Processing Record 1229: mangrol
# ---------------
# Processing Record 1229: coahuayana
# ---------------
# Processing Record 1229: aykhal
# ---------------
# Processing Record 1229: belaya gora
# ---------------
# Processing Record 1229: koumac
# ---------------
# Processing Record 1229: istok
# ---------------
# Processing Record 1229: luau
# ---------------
# Processing Record 1229: muros
# ---------------
# Processing Record 1229: faya
# ---------------
# Processing Record 1229: hirara
# ---------------
# Processing Record 1229: qaqortoq
# ---------------
# Processing Record 1229: vikindu
# ---------------
# Processing Record 1229: vaitape
# ---------------
# Processing Record 1229: abu samrah
# ---------------
# Processing Record 1229: okhotsk
# ---------------
# Processing Record 1229: rexburg
# ---------------
# Processing Record 1229: gazli
# ---------------
# Processing Record 1229: mingguang
# ---------------
# Processing Record 1229: ucluelet
# ---------------
# Processing Record 1229: santiago
# ---------------
# Processing Record 1229: olafsvik
# ---------------
# Processing Record 1229: jinchang
# ---------------
# Processing Record 1229: salvador
# ---------------
# Processing Record 1229: paamiut
# ---------------
# Processing Record 1229: cockburn harbour
# City not found. Skipping...
# ---------------
# Processing Record 1229: tunduru
# City not found. Skipping...
# ---------------
# Processing Record 1229: kralendijk
# ---------------
# Processing Record 1229: nouadhibou
# ---------------
# Processing Record 1229: finschhafen
# ---------------
# Processing Record 1229: sokoto
# ---------------
# Processing Record 1229: te anau
# ---------------
# Processing Record 1229: pekalongan
# ---------------
# Processing Record 1229: hutchinson
# ---------------
# Processing Record 1229: nova olinda do norte
# ---------------
# Processing Record 1229: antofagasta
# ---------------
# Processing Record 1229: lorengau
# ---------------
# Processing Record 1229: pitimbu
# ---------------
# Processing Record 1229: biak
# ---------------
# Processing Record 1229: meulaboh
# ---------------
# Processing Record 1229: bagotville
# ---------------
# Processing Record 1229: mayma
# ---------------
# Processing Record 1229: villamontes
# ---------------
# Processing Record 1229: ko samui
# ---------------
# Processing Record 1229: niort
# ---------------
# Processing Record 1229: bayan
# ---------------
# Processing Record 1229: puerto varas
# ---------------
# Processing Record 1229: chapais
# ---------------
# Processing Record 1229: adrar
# ---------------
# Processing Record 1229: mehran
# ---------------
# Processing Record 1229: asau
# ---------------
# Processing Record 1229: ushtobe
# ---------------
# Processing Record 1229: wynyard
# ---------------
# Processing Record 1229: dakar
# ---------------
# Processing Record 1229: luganville
# ---------------
# Processing Record 1229: bosaso
# ---------------
# Processing Record 1229: bentiu
# ---------------
# Processing Record 1229: yinchuan
# ---------------
# Processing Record 1229: gazojak
# ---------------
# Processing Record 1229: kodinsk
# ---------------
# Processing Record 1229: davila
# ---------------
# Processing Record 1229: marsa matruh
# ---------------
# Processing Record 1229: talnakh
# ---------------
# Data Retrieval Complete
# ---------------

# %%
weather_response = requests.get(query_url + cities[0]).json()
print(new_city_list)
# Out:
# ['Kapaa', 'Lata', 'Guerrero Negro', 'Tasiilaq', 'Ţaga', 'Brae', 'Kamaishi', 'Vaini', 'Naze', 'Qaanaaq', 'Deputatsky', 'Hermanus', 'Teya', 'Ushuaia', 'Ivybridge', 'Port Alfred', 'Khatanga', 'George Town', 'Saldanha', 'Rikitea', 'Busselton', 'Albany', 'Tacuarembó', 'Atuona', 'Hilo', 'Omboué', 'Port Elizabeth', 'Avarua', 'Forotic', 'Raudeberg', 'Upernavik', 'Puerto Ayora', 'Caravelas', 'Nālūt', 'Grindavik', 'Husavik', 'Karonga', 'Bethel', 'Tigzirt', 'Jamestown', 'Butaritari', 'Saint-Philippe', 'Yellowknife', 'São João do Piauí', 'Iqaluit', 'Hukuntsi', 'Darnah', 'Svetlaya', 'Nikolskoye', 'Abu Dhabi', 'Cape Town', 'Alice Springs', 'Williams Lake', 'Gamboma', 'Mariehamn', 'Voyvozh', 'Tres Arroyos', 'Esperance', 'Castlerea', 'Lavrentiya', 'Castro', 'Erciş', 'Camden', 'Ziro', 'Pacific Grove', 'Hobart', 'Jalu', 'Chui', 'Hambantota', 'Gornyy', 'Filingué', 'Carnarvon', 'Kanigoro', 'Dikson', 'Katsuura', 'Mookane', 'Talcahuano', 'Río Gallegos', 'Arandis', 'Padang', 'Kajaani', 'Atasū', 'Kendari', 'Mataura', 'Yarmouth', 'Northam', 'Aklavik', 'Arrondissement de Verdun', 'Thompson', 'Bambous Virieux', 'Vao', 'Carahue', 'Indramayu', 'Wajima', 'Punta Arenas', 'Barrow', 'Aitape', 'Baruun-Urt', 'Sitka', 'Hithadhoo', 'Plettenberg Bay', 'Kiryat Gat', 'Mar del Plata', 'Los Llanos de Aridane', 'Kirakira', 'New Norfolk', 'Sur', 'Chīma', 'Saint-Louis', 'Longyearbyen', 'Boa Vista', 'Ostrovnoy', 'Codrington', 'Karratha', 'Ribeira Grande', 'Quatre Cocos', 'Provideniya', 'La Roche-sur-Yon', 'Khovu-Aksy', 'Ayamé', 'Esim', 'Ilulissat', 'Saskylakh', 'Mora', 'Anadyr', 'Mehamn', 'Pisco', 'Mount Gambier', 'Saint-François', 'Klamath Falls', 'Ippy', 'Hong Kong', 'Kahului', 'Bilibino', 'Kaitangata', 'San Patricio', 'Lebu', 'Bredasdorp', 'Sosnovo-Ozerskoye', 'Souillac', 'Vardø', 'Arraial do Cabo', 'Mareeba', 'Airai', 'Baoqing', 'Salalah', 'Alenquer', 'Cherskiy', 'Chara', 'Kencong', 'Seoul', 'Pandan', 'Iskateley', 'Dodola', 'Cidreira', 'Coyhaique', 'Kokopo', 'Borogontsy', 'Viedma', 'Berlevåg', 'Najrān', 'Dudinka', 'Christchurch', 'Yuyao', 'Kieta', 'Harper', 'Ulaangom', 'Östersund', 'College', 'Harar', 'Qasigiannguit', 'Udachny', 'Alofi', 'Iquitos', 'Zyryanka', 'Batagay-Alyta', 'Wanning', 'Lompoc', 'Arlit', 'Ponta do Sol', 'Muravlenko', 'Bluff', 'Prince Rupert', 'Zhuhai', 'East London', 'Vuktyl', 'Safi', 'Taoudenni', 'Balabac', 'Tyukalinsk', 'Ancud', 'Vila Velha', 'Chichica', 'Norman Wells', 'Tevaitoa', 'Champerico', 'Havelock', 'Dvinskoy Bereznik', 'Chokurdakh', 'Waingapu', 'Narsaq', 'Samarai', 'Isangel', 'Faanui', 'Zhigansk', 'Port Lincoln', 'Hamilton', 'Marabu', 'Grand Gaube', 'Mogok', 'Bengkulu', 'Presidente Venceslau', 'Necochea', 'Sitārganj', 'Nabire', 'Horadiz', 'Dillon', 'Saint Paul Harbor', 'Bayir', 'Cayenne', 'Cururupu', 'Maragogi', 'Tromsø', 'Nanortalik', 'Kargil', 'Williamsburg', 'Mahébourg', 'Ondangwa', 'Walvis Bay', 'Pangnirtung', 'Coria', 'Shamary', 'Ciudad Guayana', 'Bodden Town', 'Khoy', 'Carrickmacross', 'Yangi Marg`ilon', 'Hobyo', 'La Ronge', 'Bonavista', 'Nuuk', 'Xining', 'Haines Junction', 'Mahajanga', 'Geraldton', 'Shingū', 'Kiama', 'Upata', 'Poso', 'Sagua la Grande', 'Tuktoyaktuk', 'Isiro', 'Yatsuomachi-higashikumisaka', 'Kenai', 'North Bend', 'Thinadhoo', 'Kavieng', 'Birao', 'Port Hedland', 'Teahupoo', 'Windsor', 'São João da Barra', 'Levice', 'Buguruslan', 'Nome', 'Edgewater', 'Thyborøn', 'Touros', 'Magadan', 'Lakes Entrance', 'Ordynskoye', 'Mount Isa', 'Sobolevo', 'Parole', 'Lincoln', "Severo-Kuril'sk", 'Abong Mbang', 'Puerto El Triunfo', 'Coquimbo', 'Le Port', 'Wakkanai', 'Sola', 'Lagoa', 'Shitkino', 'Henties Bay', 'Mocuba', 'Bowen', 'Tatvan', 'Rocha', 'Tuatapere', 'Wokha', 'Fuling', 'Saquena', 'Vestmannaeyjar', 'Ulladulla', 'Kruisfontein', 'Garden Acres', 'Sept-Îles', 'Saint George', 'Soyo', 'Toora-Khem', 'Troitsk', 'Gizo Government Station', 'Shubarkuduk', 'Ponta Delgada', 'Stornoway', 'Pevek', 'Emba', 'Tyukhtet', 'Chumikan', 'San Cristobal', 'Birin', 'Aktau', 'Cristalina', 'La Plata', 'Leningradskiy', 'Barra Patuca', 'Aurillac', 'Ishim', ' ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = { 
'City': new_city_list,
'Lat': latitude_list,
'Lng': longitude_list,
'Max Temp': temperature_list,
'Humidity': humidity_list,
'Cloudiness': cloudiness_list,
'Wind Speed': wind_speed_list,
'Country': country_list
}

weather_df = pd.DataFrame(weather_dict)
weather_df

weather_df.to_csv(r"C:\Users\robma\homework\python-api-challenge\weatherpy\csv_file\weather.csv", index=False, header=True)

# %%
weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa  22.0752 -159.3190      71.6        49          40
# 1            Lata  40.1629   -8.3327      55.0        90          92
# 2  Guerrero Negro  27.9769 -114.0611      57.9        85           0
# 3        Tasiilaq  65.6145  -37.6368      14.0        62          75
# 4            Ţaga  46.9500   24.0500      43.0       100          75
#
#    Wind Speed Country
# 0       13.80      US
# 1        1.99      PT
# 2       11.88      MX
# 3        3.44      GL
# 4        2.30      RO

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  558.000000  558.000000  558.000000  558.000000  558.000000  558.000000
# mean    19.410319   22.448192   48.673566   75.293907   52.370968    7.407115
# std     34.120133   89.941648   32.082990   18.647914   39.271376    5.544937
# min    -54.800000 -175.200000  -40.000000   12.000000    0.000000    0.110000
# 25%     -8.904150  -58.707550   25.860000   67.000000    8.000000    3.440000
# 50%     23.408350   23.710800   59.595000   80.000000   61.000000    6.210000
# 75%     48.541325  100.349575   74.140000   89.000000   90.000000   10.347500
# max     78.218600  178.416700   99.000000  100.000000  100.000000   36.080000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
test = weather_df.loc[weather_df['Humidity'] > 100]
test

#cities_100 = weather_df[weather_df['Humidity'] > 100].index.tolist()
#cities_100
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country]
# Index: []

# %%
print('There are no cities with humidity > 100%. Skipping next step.')
# Out:
# There are no cities with humidity > 100%. Skipping next step.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#weather_df.drop(weather_df[weather_df['Humidity'] >100].index, inplace=False)
#weather_df

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_axis_lat = weather_df['Lat']
y_axis_temp = weather_df['Max Temp']
plt.scatter(x_axis_lat, y_axis_temp, marker="o", facecolors="blue", edgecolors="black", alpha=0.50)
plt.xlabel('City Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude Vs. Max Temperature ')
plt.savefig('output\latitude_vs_temperature.png')

# %% [markdown]
# This plot visualizes the relationship between the city's latitude and its maximum temperature. As the latitude increases the max temperature decreases.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
y_axis_hum = weather_df['Humidity']
plt.scatter(x_axis_lat, y_axis_hum, marker="o", facecolors="blue", edgecolors="black", alpha=0.50)
plt.xlabel('City Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude Vs. Humidity ')
plt.savefig('output\latitude_vs_humidity.png')

# %% [markdown]
# This plot visualizes the relationship between the city latitude and percent humidity. There are more cities with higher levels of humidity than cities with a lower percentage of humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
y_axis_cloud = weather_df['Cloudiness']
plt.scatter(x_axis_lat, y_axis_cloud, marker="o", facecolors="blue", edgecolors="black", alpha=0.50)
plt.xlabel('City Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude Vs. Cloudiness ')
plt.savefig('output\latitude_vs_cloudiness.png')

# %% [markdown]
# City Latitude vs. Cloudiness- There appears to be clusters of cities with percentages of cloudiness at 100%, 80%, 40%, and 0%.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
y_axis_wind = weather_df['Wind Speed']
plt.scatter(x_axis_lat, y_axis_wind, marker="o", facecolors="blue", edgecolors="black", alpha=0.50)
plt.xlabel('City Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude Vs. Wind Speed ')
plt.savefig('output\latitude_vs_windspeed.png')

# %% [markdown]
# The majority of cities have wind speeds below 15 mph.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_weather_df = weather_df.loc[weather_df['Lat'] >= 0]
north_weather_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Kapaa  22.0752 -159.3190     71.60        49          40
# 1              Lata  40.1629   -8.3327     55.00        90          92
# 2    Guerrero Negro  27.9769 -114.0611     57.90        85           0
# 3          Tasiilaq  65.6145  -37.6368     14.00        62          75
# 4              Ţaga  46.9500   24.0500     43.00       100          75
# ..              ...      ...       ...       ...       ...         ...
# 553         Gazojak  41.1875   61.4036     43.56        65         100
# 554         Kodinsk  58.6881   99.1844     -0.11        87          75
# 555          Davila  18.4726  120.5763     86.00        58          75
# 556    Marsá Maţrūḩ  31.3525   27.2453     46.40        66          18
# 557         Talnakh  69.4865   88.3972     -8.61        90          97
#
#      Wind Speed Country
# 0         13.80      US
# 1          1.99      PT
# 2         11.88      MX
# 3          3.44      GL
# 4          2.30      RO
# ..          ...     ...
# 553       10.76      TM
# 554        9.17      RU
# 555        5.75      PH
# 556        2.30      EG
# 557        3.20      RU
#
# [373 rows x 8 columns]

# %%
# Generate new variables to designate northern hemisphere data
north_weather_df = weather_df.loc[weather_df['Lat'] >= 0]
x_lat_north = north_weather_df['Lat']
y_temp_north = north_weather_df['Max Temp']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_north, y_temp_north)
regress_values = x_lat_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_north, y_temp_north, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_north,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Northern Hemisphere- Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.savefig(r'output\north_lat_temp.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7743926975253127

# %% [markdown]
#  Cities with higher latitudes (more northern) tend to have lower max temperatures.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_weather_df = weather_df.loc[weather_df['Lat'] <= 0]
x_lat_south = south_weather_df['Lat']
y_temp_south = south_weather_df['Max Temp']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_south, y_temp_south)
regress_values = x_lat_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_south, y_temp_south, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_south,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Southern Hemisphere- Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.savefig(r'output\south_lat_temp.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.30344199334811356

# %% [markdown]
# As the latitude approaches 0 (Equator), the max temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_weather_df = weather_df.loc[weather_df['Lat'] >= 0]
x_lat_north = north_weather_df['Lat']
y_hum_north = north_weather_df['Humidity']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_north, y_hum_north)
regress_values = x_lat_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_north, y_hum_north, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_north,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Northern Hemisphere- Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig(r'output\north_lat_humidity.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.09345158932631577

# %% [markdown]
# There is no clearly defined relationship between a city's latitude and the percent humidity in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_weather_df = weather_df.loc[weather_df['Lat'] <= 0]
x_lat_south = south_weather_df['Lat']
y_hum_south = south_weather_df['Humidity']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_south, y_hum_south)
regress_values = x_lat_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_south, y_hum_south, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_south,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Southern Hemisphere- Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig(r'output\south_lat_humidity.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.013463572481132027

# %% [markdown]
# There is no clearly defined relationship between a city's latitude and the percent humidity in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_weather_df = weather_df.loc[weather_df['Lat'] >= 0]
x_lat_north = north_weather_df['Lat']
y_cloud_north = north_weather_df['Cloudiness']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_north, y_cloud_north)
regress_values = x_lat_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_north, y_cloud_north, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_north,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Northern Hemisphere- Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig(r'output\north_lat_cloudy.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.024594843078901897

# %% [markdown]
# There is no clearly defined relationship between cloudiness and a city's latitude in the northern hemisphere. Cities appear to cluster around specific percentages of cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_weather_df = weather_df.loc[weather_df['Lat'] <= 0]
x_lat_south = south_weather_df['Lat']
y_cloud_south = south_weather_df['Cloudiness']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_south, y_cloud_south)
regress_values = x_lat_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_south, y_cloud_south, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_south,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Southern Hemisphere- Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig(r'output\south_lat_cloudy.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.12161143872833759

# %% [markdown]
# There is no clearly defined relationship between cloudiness and a city's latitude in the southern hemisphere. Cities appear to cluster around specific percentages of cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_weather_df = weather_df.loc[weather_df['Lat'] >= 0]
x_lat_north = north_weather_df['Lat']
y_wind_north = north_weather_df['Wind Speed']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_north, y_wind_north)
regress_values = x_lat_north * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_north, y_wind_north, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_north,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Northern Hemisphere- Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig(r'output\north_lat_windspeed.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0035765603996266056

# %% [markdown]
# Windspeed does not appear to be affected by latitude in the northern hemisphere. The majority of cities in this population have a wind speed of 15 mph or less.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_weather_df = weather_df.loc[weather_df['Lat'] <= 0]
x_lat_south = south_weather_df['Lat']
y_wind_south = south_weather_df['Wind Speed']
#create plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_lat_south, y_wind_south)
regress_values = x_lat_south * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_lat_south, y_wind_south, marker='o', facecolor='blue', edgecolor='black')
plt.plot(x_lat_south,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Southern Hemisphere- Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig(r'output\south_lat_windspeed.png')
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.012294013420914606

# %% [markdown]
# Windspeed does not appear to be affected by latitude in the southern hemisphere. The majority of cities in this population have a wind speed of 15 mph or less.
